# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/User/Downloads/attrition data.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Missing values in the entire DataFrame
print(data.isnull().sum())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Duplicate rows in the entire DataFrame
print(data.duplicated().sum())
# Out:
# 0

# %%
nrow, ncol = data.shape
print("no.of rows:", nrow)
print("no.of columns:", ncol)
# Out:
# no.of rows: 1470
# no.of columns: 35

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

numerical_columns = [
    'Age', 'DistanceFromHome', 'MonthlyIncome', 
    'NumCompaniesWorked', 'TotalWorkingYears', 
    'TrainingTimesLastYear', 'YearsAtCompany', 
    'YearsInCurrentRole', 'YearsSinceLastPromotion', 
    'YearsWithCurrManager'
]

# Box plots for each numerical attribute to identify outliers
plt.figure(figsize=(16, 10))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(data=data[col])
    plt.title(col)
plt.tight_layout()
plt.show()


print(data[numerical_columns].describe())

# outliers detection using z-score method
outliers = {}
for col in numerical_columns:
    z_scores = np.abs((data[col] - data[col].mean()) / data[col].std())
    outliers[col] = data[z_scores > 3]


for col, outliers_df in outliers.items():
    print(f'Outliers in {col}:')
    print(outliers_df)
# Out:
#                Age  DistanceFromHome  MonthlyIncome  NumCompaniesWorked  \
# count  1470.000000       1470.000000    1470.000000         1470.000000
# mean     36.923810          9.192517    6502.931293            2.693197
# std       9.135373          8.106864    4707.956783            2.498009
# min      18.000000          1.000000    1009.000000            0.000000
# 25%      30.000000          2.000000    2911.000000            1.000000
# 50%      36.000000          7.000000    4919.000000            2.000000
# 75%      43.000000         14.000000    8379.000000            4.000000
# max      60.000000         29.000000   19999.000000            9.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# count        1470.000000            1470.000000     1470.000000
# mean           11.279592               2.799320        7.008163
# std             7.780782               1.289271        6.126525
# ...

# %%
emp_data = pd.get_dummies(data,columns=["BusinessTravel"],drop_first=True)

# %%
print(emp_data)
# Out:
#       Age Attrition  DailyRate              Department  DistanceFromHome  \
# 0      41       Yes       1102                   Sales                 1
# 1      49        No        279  Research & Development                 8
# 2      37       Yes       1373  Research & Development                 2
# 3      33        No       1392  Research & Development                 3
# 4      27        No        591  Research & Development                 2
# ...   ...       ...        ...                     ...               ...
# 1465   36        No        884  Research & Development                23
# 1466   39        No        613  Research & Development                 6
# 1467   27        No        155  Research & Development                 4
# 1468   49        No       1023                   Sales                 2
# 1469   34        No        628  Research & Development                 8
#
#       Education EducationField  EmployeeCount  EmployeeNumber  \
# ...

# %%
emp_data = pd.get_dummies(emp_data,columns=["Department"],drop_first=True)

# %%
emp_data = pd.get_dummies(emp_data,columns=["EducationField"],drop_first=True)

# %%
emp_data = pd.get_dummies(emp_data,columns=["JobRole"],drop_first=True)

# %%
print(emp_data)
# Out:
#       Age Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       Yes       1102                 1          2              1
# 1      49        No        279                 8          1              1
# 2      37       Yes       1373                 2          2              1
# 3      33        No       1392                 3          4              1
# 4      27        No        591                 2          1              1
# ...   ...       ...        ...               ...        ...            ...
# 1465   36        No        884                23          2              1
# 1466   39        No        613                 6          1              1
# 1467   27        No        155                 4          3              1
# 1468   49        No       1023                 2          3              1
# 1469   34        No        628                 8          3              1
#
# ...

# %%
order_label={"No":0,"Yes":1}

# %%
emp_data["Attrition"]=emp_data["Attrition"].map(order_label)

# %%
emp_data.head(5)
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   41          1       1102                 1          2              1
# 1   49          0        279                 8          1              1
# 2   37          1       1373                 2          2              1
# 3   33          0       1392                 3          4              1
# 4   27          0        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0               1                        2  Female          94  ...
# 1               2                        3    Male          61  ...
# 2               4                        4    Male          92  ...
# 3               5                        4  Female          56  ...
# 4               7                        1    Male          40  ...
#
#    EducationField_Other  EducationField_Technical Degree  \
# ...
